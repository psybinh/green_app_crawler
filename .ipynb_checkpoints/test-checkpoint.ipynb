# %%
import pandas as pd

data = pd.read_json('EliteBook-datetime-2019-09-20-15-42.csv', lines=True)
data
# Out:
#     HouseholdViewModel.HouseholdSize  \
# 0                                  5
# 1                                 11
# 2                                 11
# 3                                  3
# 4                                  7
# 5                                  7
# 6                                  6
# 7                                  3
# 8                                  8
# 9                                  4
# 10                                 1
# 11                                11
# 12                                 7
# 13                                 5
# 14                                 7
# 15                                11
# 16                                10
# 17                                 2
# 18                                 6
# 19                                 1
# 20                                 8
# 21                                 7
# 22                                 9
# 23                                 7
# ...
